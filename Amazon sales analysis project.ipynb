# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Sandeep\Downloads\Amazon Sales data.csv")

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %%
import datetime as dt

# %%
df['Year'] = df['Order Date'].dt.year

# %%
df['Month'] = df['Order Date'].dt.month

# %%
monthly_sales = df.groupby(['Month'])['Total Revenue'].sum().reset_index()

# %%
yearly_sales = df.groupby(['Year'])['Total Revenue'].sum().reset_index()

# %%
yearly_month_sales = df.groupby(['Year',"Month"])['Total Revenue'].sum().reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(data = monthly_sales, x = 'Month',y= 'Total Revenue')
plt.title('Monthly Sales Trends')
plt.show()

# %%
sns.barplot(data=yearly_sales, x='Year', y='Total Revenue')
plt.title('Yearly Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data = yearly_month_sales, x = 'Month',y = 'Total Revenue', hue = 'Year')
plt.title('Yearly_month_wise_trends')
plt.show()

# %%
test_data = df[['Units Sold','Unit Price','Unit Cost','Total Revenue','Total Cost','Total Profit']]

# %%
test_data.corr()
# Out:
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000   -0.070486  -0.092232       0.447784    0.374746
# Unit Price      -0.070486    1.000000   0.987270       0.752360    0.787905
# Unit Cost       -0.092232    0.987270   1.000000       0.715623    0.774895
# Total Revenue    0.447784    0.752360   0.715623       1.000000    0.983928
# Total Cost       0.374746    0.787905   0.774895       0.983928    1.000000
# Total Profit     0.564550    0.557365   0.467214       0.897327    0.804091
#
#                Total Profit
# Units Sold         0.564550
# Unit Price         0.557365
# Unit Cost          0.467214
# Total Revenue      0.897327
# Total Cost         0.804091
# Total Profit       1.000000

# %%
sns.heatmap(test_data.corr())
# Out:
# <Axes: >

# %%
#key metrics

# %%
#financial metrics

# %%
df['Profit'] = df['Total Revenue'] - df['Total Cost']

# %%
df['profit margin(%)'] = (df['Profit']/df['Total Revenue'])*100

# %%
#Time based metrics

# %%
monthly_trends = df.groupby(['Year', 'Month']).agg({
    'Total Revenue': 'sum',
    'Profit': 'sum'
}).reset_index()
print(monthly_trends.head())
# Out:
#    Year  Month  Total Revenue      Profit
# 0  2010      2     3410661.12  1424410.94
# 1  2010      5     2587973.26   965441.52
# 2  2010      6     1082418.40   727423.20
# 3  2010     10     6064933.75  1495392.79
# 4  2010     11     3458252.00  1375311.70

# %%
yearly_trends = df.groupby('Year').agg({
    'Total Revenue': 'sum',
    'Total Cost': 'sum',
    'Profit': 'sum'
}).reset_index()
print(yearly_trends)
# Out:
#    Year  Total Revenue   Total Cost      Profit
# 0  2010    19186024.92  12556457.49  6629567.43
# 1  2011    11129166.07   8388157.84  2741008.23
# 2  2012    31898644.52  22685634.40  9213010.12
# 3  2013    20330448.66  13615028.62  6715420.04
# 4  2014    16630214.43  10750752.75  5879461.68
# 5  2015    12427982.86   8431443.42  3996539.44
# 6  2016    12372867.22   7469029.21  4903838.01
# 7  2017    13373419.63   9284066.18  4089353.45

# %%
#growth_rate
df['Revenue Growth(%)'] = df['Total Revenue'].pct_change()*100

# %%
#shipping metrics

# %%
df['Shipping Duration'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
average_shipping_duration = df['Shipping Duration'].mean()
print(f"Average Shipping Duration: {average_shipping_duration:.2f} days")
# Out:
# Average Shipping Duration: 23.36 days

# %%
sns.lineplot(data=monthly_trends, x='Month', y='Profit', hue='Year', marker='o')
plt.title('Monthly Profit Trends')
plt.xlabel('Month')
plt.ylabel('Profit')
plt.show()

# %%
sns.histplot(df['Shipping Duration'], bins=10, kde=True)
plt.title('Shipping Duration Distribution')
plt.xlabel('Days')
plt.ylabel('Frequency')
plt.show()

# %%
#region metrics

# %%
region_metrics = df.groupby('Region').agg({
    'Total Revenue': 'sum',
    'Profit': 'sum'
}).reset_index()

print(region_metrics)
# Out:
#                               Region  Total Revenue       Profit
# 0                               Asia    21347091.02   6113845.87
# 1              Australia and Oceania    14094265.13   4722160.03
# 2  Central America and the Caribbean     9170385.49   2846907.85
# 3                             Europe    33368932.11  11082938.63
# 4       Middle East and North Africa    14052706.58   5761191.86
# 5                      North America     5643356.55   1457942.76
# 6                 Sub-Saharan Africa    39672031.43  12183211.40

# %%
sns.barplot(data=region_metrics, x='Region', y='Total Revenue')
plt.title('Revenue by Region')
plt.xlabel('Region')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
monthly_trends.to_csv('monthly_trends.csv', index=False)
region_metrics.to_csv('region_metrics.csv', index=False)
